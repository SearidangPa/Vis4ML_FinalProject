# %%
import pandas as pd
import altair as alt
import pmlb
import warnings
warnings.filterwarnings('ignore')

# %%
### Load the dataframe to be visualized 
Indiv_filename = '../Data/4vis/Indiv.pkl'
Indiv_df = pd.read_pickle(Indiv_filename)
dict_method_name_to_attr_name = {
    'shap' : 'shap_value',
    'lime': 'lime_weight', 
    'ig':  'ig_attr', 
    'deepLift':'deepLift_attr' 
}

# %% [markdown]
# ## Make the chart

# %%
num_samples = 5000
sorted_features = Indiv_df.groupby(['feature_name']).sum().sort_values(by = ['sum_rank'], ascending = False).index.values.tolist()
base = alt.Chart(data=Indiv_df.sample(n=num_samples, random_state=42)).mark_circle().encode(
    row=alt.Row('feature_name', sort=sorted_features, spacing=0, header=alt.Header(labelAngle=0, labelAlign='left')),
    y=alt.Y('jitter:Q', axis=None),
    color=alt.Color('feature_value', scale=alt.Scale(scheme='viridis'), title=None),
    size=alt.value(32)
).properties(
    width=600,
    height=80
).transform_calculate(
    jitter='random()'
).resolve_scale(
    color='independent'
)

charts = {}
for _, attr_name in dict_method_name_to_attr_name.items():
    charts[attr_name] = base.encode(x = attr_name).properties(
       width=300,
        height=40
    )

# %% [markdown]
# ### Summary Strip Plot

# %%
view_row1 = charts['shap_value'] | charts['lime_weight'] 
row2 = charts['lime_weight'] | charts['ig_attr']
chart = alt.vconcat(view_row1, row2)
chart
# Out:
# alt.VConcatChart(...)
